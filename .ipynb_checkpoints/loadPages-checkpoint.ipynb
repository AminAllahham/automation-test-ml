# %%
import tensorflow as tf


print(tf.__version__)
# Out:
# 2.4.0-rc0

# %%
#_*_coding: utf-8_*_

from selenium import webdriver

browser = webdriver.Chrome()

browser.get('https://opexams.app/login?redirect=%2F')
result = browser.execute_script('var text = document.title ; return text')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/pj/6vmyt5l94ng8qrmgqds2qc9m0000gn/T/ipykernel_22905/1408818449.py in <module>
#       6
#       7 browser.get('https://opexams.app/login?redirect=%2F')
# ----> 8 result = driver.execute_script('var text = document.title ; return text')
#       9
#
# NameError: name 'driver' is not defined
