# %%
import tensorflow as tf


print(tf.__version__)
# Out:
# 2.4.0-rc0

# %%
from selenium import webdriver

browser = webdriver.Chrome()

browser.get('https://opexams.app')
innerHTML = browser.execute_script("return document.body.innerHTML")
foundUrls = []


print(innerHTML)
# Out:
# <noscript>You need to enable JavaScript to run this app.</noscript><div id="root"><div class="App ltr"><div style="display: none;"></div><div style="width: 100%; height: 100%;"><div class="App ltr"><div style="display: none;"></div><div style="width: 100%; height: 100%;"><div><div></div><div style="width: 100vw; height: 100vh;"><div class="jss43"><div style="width: 100%; height: 100%;"><div class="jss44" style="width: 1200px; height: 887px;"><div class="jss59"><div class="jss60"><img src="https://opexams.app/0e5249c86af5932a4beea3704dc5af7f.svg" class="jss61"><div class="jss66"><a href="https://opexams.com" class="jss70 jss67">Learn More</a></div><div class="jss62"><div class="jss71 jss69"><p class="MuiTypography-root-82 jss74 MuiTypography-body1-84">English</p><svg stroke="currentColor" fill="currentColor" stroke-width="0" viewBox="0 0 512 512" class="jss112 jss75" height="1em" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M128 192l128 128 128-128z"></path></svg></div><div
# ...
